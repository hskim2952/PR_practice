# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random

# %%
def resumetable(df):
    print(f'Dataset shape: {df.shape}')
    summary = pd.DataFrame(df.dtypes, columns=['Data Type'])
    summary = summary.reset_index()
    summary = summary.rename(columns={'index': 'Feature'})
    summary['Missing Values Count'] = df.isnull().sum().values
    summary['Missing Values Percentage'] = df.isnull().sum().values / len(df) * 100
    summary['Unique Values Count'] = df.nunique().values
    summary['First Value'] = df.iloc[0].values
    summary['Second Value'] = df.iloc[1].values
    summary['Third Value'] = df.iloc[2].values
    summary['Second to Last Value'] = df.iloc[-2].values
    summary['Last Value'] = df.iloc[-1].values
    return summary

def seed_everything(seed = 9234):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    # torch.manual_seed(seed)
    # torch.cuda.manual_seed(seed)
    # torch.backends.cudnn.deterministic = True
    # torch.backends.cudnn.benchmark = True

seed_everything()

# %%
data = pd.read_csv("../Data/Soo_T_PATIENTS_DAILY_WHOLE_0812.csv")

# %%
data = data.drop(columns=["updtDate", "instDate", "sat_x", "sat_y", "sido", "create_date"])

# %%
resumetable(data)
# Out:
# Dataset shape: (26010, 53)
#               Feature Data Type  Missing Values Count  \
# 0             sido_cd     int64                     0
# 1          weekend_yn     int64                     0
# 2              grid_x     int64                     0
# 3              grid_y     int64                     0
# 4              min_ta   float64                     0
# 5              max_ta   float64                     0
# 6             mean_ta   float64                     0
# 7              gap_ta   float64                     0
# 8          min_tafeel   float64                     0
# 9          max_tafeel   float64                     0
# 10        mean_tafeel   float64                     0
# 11         gap_tafeel   float64                     0
# 12             min_hm   float64                     0
# 13             max_hm   float64                     0
# 14            mean_hm   float64                     0
# 15             gap_hm   float64                     0
# 16         min_wbtemp   float64                     0
# 17         max_wbtemp   float64                     0
# 18        mean_wbtemp   float64                     0
# 19         gap_wbtemp   float64                     0
# 20             min_ws   float64                     0
# 21             max_ws   float64                     0
# 22            mean_ws   float64                     0
# 23     tropical_3days     int64                     0
# 24      heatwave_temp     int64                     0
# 25     heatalert_temp     int64                     0
# 26       ta_min_3days   float64                     0
# 27       ta_max_3days   float64                     0
# 28      gap_ta_minmax   float64                     0
# 29        popular_man     int64                     0
# 30      popular_woman     int64                     0
# 31    agriculture_man     int64                     0
# 32  agriculture_woman     int64                     0
# 33          ta_min_am     int64                     0
# 34          ta_max_am     int64                     0
# 35         ta_mean_am     int64                     0
# 36          ta_min_pm     int64                     0
# 37          ta_max_pm     int64                     0
# 38         ta_mean_pm     int64                     0
# 39     ta_min_six_am1   float64                     0
# 40     ta_max_six_am1   float64                     0
# 41    ta_mean_six_am1   float64                     0
# 42     ta_min_six_am2     int64                     0
# 43     ta_max_six_am2     int64                     0
# 44    ta_mean_six_am2     int64                     0
# 45     ta_min_six_pm1     int64                     0
# 46     ta_max_six_pm1     int64                     0
# 47    ta_mean_six_pm1     int64                     0
# 48     ta_min_six_pm2     int64                     0
# 49     ta_max_six_pm2     int64                     0
# 50    ta_mean_six_pm2     int64                     0
# 51        patientsCnt     int64                     0
# 52      jenks_cluster     int64                     0
#
#     Missing Values Percentage  Unique Values Count  First Value  Second Value  \
# 0                         0.0                   17        31.00         33.00
# 1                         0.0                    2         0.00          0.00
# 2                         0.0                   15        60.00         69.00
# 3                         0.0                   16       120.00        107.00
# 4                         0.0                  253         9.60         10.50
# 5                         0.0                  259        24.20         23.70
# 6                         0.0                  231        16.60         17.10
# 7                         0.0                  194        14.60         13.20
# 8                         0.0                 2144        12.35         12.78
# 9                         0.0                 1943        22.04         22.16
# 10                        0.0                  223        17.00         17.50
# 11                        0.0                  142         9.70          9.40
# 12                        0.0                   97        30.00         33.00
# 13                        0.0                   73        98.00         91.00
# 14                        0.0                  739        61.10         60.00
# 15                        0.0                  120         5.40          5.60
# 16                        0.0                  246         8.80          9.30
# 17                        0.0                  234        14.20         14.90
# 18                        0.0                  229        11.60         12.00
# 19                        0.0                  120         5.40          5.60
# 20                        0.0                   76         0.30          0.00
# 21                        0.0                   91         3.50          3.70
# 22                        0.0                   96         1.70          1.60
# 23                        0.0                    4         0.00          0.00
# 24                        0.0                   49         0.00          0.00
# 25                        0.0                   37         0.00          0.00
# 26                        0.0                  243         9.60         10.50
# 27                        0.0                  246        24.20         23.70
# 28                        0.0                  213        14.60         13.20
# 29                        0.0                  170   6219813.00     796141.00
# 30                        0.0                  170   6138017.00     782792.00
# 31                        0.0                  169    186278.00      92687.00
# 32                        0.0                  169    188594.00      95065.00
# 33                        0.0                   28         9.00         10.00
# 34                        0.0                   30        21.00         21.00
# 35                        0.0                   25        13.00         14.00
# 36                        0.0                   27        14.00         15.00
# 37                        0.0                   30        24.00         23.00
# 38                        0.0                   28        20.00         20.00
# 39                        0.0                   29         9.00         10.00
# 40                        0.0                   27        13.00         14.00
# 41                        0.0                   27        10.00         12.00
# 42                        0.0                   28         9.00         10.00
# 43                        0.0                   30        21.00         21.00
# 44                        0.0                   26        15.00         15.00
# 45                        0.0                   29        21.00         21.00
# 46                        0.0                   30        24.00         23.00
# 47                        0.0                   29        22.00         22.00
# 48                        0.0                   27        14.00         15.00
# 49                        0.0                   30        21.00         22.00
# 50                        0.0                   28        17.00         18.00
# 51                        0.0                   42         0.00          0.00
# 52                        0.0                    3         0.00          0.00
#
#     Third Value  Second to Last Value  Last Value
# 0         22.00                 38.00       23.00
# 1          0.00                  1.00        1.00
# 2         89.00                 91.00       55.00
# 3         90.00                 77.00      124.00
# 4         13.50                 18.30       18.90
# 5         25.30                 25.50       23.30
# 6         19.00                 21.50       21.50
# 7         11.80                  7.20        4.40
# 8         16.29                 20.86       20.11
# 9         23.66                 25.05       25.09
# 10        19.60                 23.10       23.00
# 11         7.40                  4.20        5.00
# 12        27.00                 49.00       62.00
# 13        97.00                 94.00       84.00
# 14        64.70                 76.70       75.30
# 15         3.40                  4.70        5.10
# 16        12.70                 15.90       15.30
# 17        16.10                 20.60       20.40
# 18        14.20                 18.40       18.30
# 19         3.40                  4.70        5.10
# 20         0.10                  0.00        0.20
# 21         3.70                  3.30        6.70
# 22         1.90                  1.30        4.10
# 23         0.00                  0.00        0.00
# 24         0.00                  0.00        0.00
# 25         0.00                  0.00        0.00
# 26        13.50                 18.30       18.30
# 27        25.30                 30.80       25.00
# 28        11.80                 12.50        6.70
# 29   1241119.00            1636987.00  1499016.00
# 30   1252145.00            1614171.00  1498394.00
# 31     25045.00             114000.00    11835.00
# 32     24142.00             121775.00    12309.00
# 33        13.00                 18.00       20.00
# 34        21.00                 22.00       23.00
# 35        16.00                 21.00       21.00
# 36        18.00                 18.00       18.00
# 37        25.00                 25.00       23.00
# 38        22.00                 21.00       21.00
# 39        13.00                 21.00       20.00
# 40        14.00                 22.00       21.00
# 41        14.00                 22.00       20.00
# 42        14.00                 18.00       21.00
# 43        21.00                 21.00       23.00
# 44        17.00                 20.00       22.00
# 45        21.00                 21.00       21.00
# 46        25.00                 25.00       23.00
# 47        23.00                 23.00       22.00
# 48        18.00                 18.00       18.00
# 49        24.00                 22.00       21.00
# 50        20.00                 19.00       20.00
# 51         0.00                  0.00        0.00
# 52         0.00                  0.00        0.00

# %%
sns.scatterplot(data=data, x="mean_ws", y="jenks_cluster")
# Out:
# <Axes: xlabel='mean_ws', ylabel='jenks_cluster'>

# %%
# !pip install optuna

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
import optuna
from sklearn.metrics import accuracy_score

# %%
X = data.drop(columns=["jenks_cluster", "patientsCnt"])
y = data.jenks_cluster

seed_num = 43

X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=seed_num)
X_train, X_valid, y_train, y_valid = train_test_split(X_temp, y_temp, test_size=0.125, stratify=y_temp, random_state=seed_num)

# %%
X_train.shape, X_valid.shape, X_test.shape
# Out:
# ((18207, 51), (2601, 51), (5202, 51))

# %%
y_train.shape, y_valid.shape, y_test.shape
# Out:
# ((18207,), (2601,), (5202,))

# %%
params = {
    "n_estimators": 200,
    "max_depth": 8,
    "learning_rate": 0.01,
    "subsample": 0.8,
    "random_state": 42,
}

model = XGBClassifier(**params)
model.fit(
    X_train, y_train,
    eval_set=[(X_valid, y_valid)],
)
# Out:
# [0]	validation_0-mlogloss:1.08837
# [1]	validation_0-mlogloss:1.07835
# [2]	validation_0-mlogloss:1.06856
# [3]	validation_0-mlogloss:1.05897
# [4]	validation_0-mlogloss:1.04955
# [5]	validation_0-mlogloss:1.04023
# [6]	validation_0-mlogloss:1.03105
# [7]	validation_0-mlogloss:1.02205
# [8]	validation_0-mlogloss:1.01322
# [9]	validation_0-mlogloss:1.00454
# [10]	validation_0-mlogloss:0.99595
# [11]	validation_0-mlogloss:0.98753
# [12]	validation_0-mlogloss:0.97929
# [13]	validation_0-mlogloss:0.97114
# [14]	validation_0-mlogloss:0.96318
# [15]	validation_0-mlogloss:0.95520
# [16]	validation_0-mlogloss:0.94744
# [17]	validation_0-mlogloss:0.93980
# [18]	validation_0-mlogloss:0.93226
# [19]	validation_0-mlogloss:0.92487
# [20]	validation_0-mlogloss:0.91760
# [21]	validation_0-mlogloss:0.91042
# [22]	validation_0-mlogloss:0.90330
# [23]	validation_0-mlogloss:0.89632
# [24]	validation_0-mlogloss:0.88943
# [25]	validation_0-mlogloss:0.88269
# [26]	validation_0-mlogloss:0.87607
# [27]	validation_0-mlogloss:0.86946
# [28]	validation_0-mlogloss:0.86297
# [29]	validation_0-mlogloss:0.85668
# [30]	validation_0-mlogloss:0.85033
# [31]	validation_0-mlogloss:0.84411
# [32]	validation_0-mlogloss:0.83798
# [33]	validation_0-mlogloss:0.83190
# [34]	validation_0-mlogloss:0.82594
# [35]	validation_0-mlogloss:0.82007
# [36]	validation_0-mlogloss:0.81430
# [37]	validation_0-mlogloss:0.80864
# [38]	validation_0-mlogloss:0.80306
# [39]	validation_0-mlogloss:0.79753
# [40]	validation_0-mlogloss:0.79210
# [41]	validation_0-mlogloss:0.78677
# [42]	validation_0-mlogloss:0.78143
# [43]	validation_0-mlogloss:0.77620
# [44]	validation_0-mlogloss:0.77100
# [45]	validation_0-mlogloss:0.76596
# [46]	validation_0-mlogloss:0.76091
# [47]	validation_0-mlogloss:0.75600
# [48]	validation_0-mlogloss:0.75114
# [49]	validation_0-mlogloss:0.74631
# [50]	validation_0-mlogloss:0.74156
# [51]	validation_0-mlogloss:0.73688
# [52]	validation_0-mlogloss:0.73225
# [53]	validation_0-mlogloss:0.72770
# [54]	validation_0-mlogloss:0.72322
# [55]	validation_0-mlogloss:0.71875
# [56]	validation_0-mlogloss:0.71435
# [57]	validation_0-mlogloss:0.71004
# [58]	validation_0-mlogloss:0.70576
# [59]	validation_0-mlogloss:0.70160
# [60]	validation_0-mlogloss:0.69744
# [61]	validation_0-mlogloss:0.69338
# [62]	validation_0-mlogloss:0.68936
# [63]	validation_0-mlogloss:0.68534
# [64]	validation_0-mlogloss:0.68141
# [65]	validation_0-mlogloss:0.67755
# [66]	validation_0-mlogloss:0.67374
# [67]	validation_0-mlogloss:0.67000
# [68]	validation_0-mlogloss:0.66624
# [69]	validation_0-mlogloss:0.66258
# [70]	validation_0-mlogloss:0.65897
# [71]	validation_0-mlogloss:0.65536
# [72]	validation_0-mlogloss:0.65186
# [73]	validation_0-mlogloss:0.64842
# [74]	validation_0-mlogloss:0.64498
# [75]	validation_0-mlogloss:0.64152
# [76]	validation_0-mlogloss:0.63816
# [77]	validation_0-mlogloss:0.63484
# [78]	validation_0-mlogloss:0.63155
# [79]	validation_0-mlogloss:0.62832
# [80]	validation_0-mlogloss:0.62506
# [81]	validation_0-mlogloss:0.62193
# [82]	validation_0-mlogloss:0.61879
# [83]	validation_0-mlogloss:0.61573
# [84]	validation_0-mlogloss:0.61263
# [85]	validation_0-mlogloss:0.60961
# [86]	validation_0-mlogloss:0.60662
# [87]	validation_0-mlogloss:0.60365
# [88]	validation_0-mlogloss:0.60077
# [89]	validation_0-mlogloss:0.59790
# [90]	validation_0-mlogloss:0.59508
# [91]	validation_0-mlogloss:0.59231
# [92]	validation_0-mlogloss:0.58953
# [93]	validation_0-mlogloss:0.58683
# [94]	validation_0-mlogloss:0.58409
# [95]	validation_0-mlogloss:0.58147
# [96]	validation_0-mlogloss:0.57882
# [97]	validation_0-mlogloss:0.57624
# [98]	validation_0-mlogloss:0.57365
# [99]	validation_0-mlogloss:0.57113
# [100]	validation_0-mlogloss:0.56861
# [101]	validation_0-mlogloss:0.56611
# [102]	validation_0-mlogloss:0.56364
# [103]	validation_0-mlogloss:0.56121
# [104]	validation_0-mlogloss:0.55884
# [105]	validation_0-mlogloss:0.55646
# [106]	validation_0-mlogloss:0.55412
# [107]	validation_0-mlogloss:0.55183
# [108]	validation_0-mlogloss:0.54957
# [109]	validation_0-mlogloss:0.54730
# [110]	validation_0-mlogloss:0.54507
# [111]	validation_0-mlogloss:0.54282
# [112]	validation_0-mlogloss:0.54062
# [113]	validation_0-mlogloss:0.53848
# [114]	validation_0-mlogloss:0.53634
# [115]	validation_0-mlogloss:0.53425
# [116]	validation_0-mlogloss:0.53218
# [117]	validation_0-mlogloss:0.53013
# [118]	validation_0-mlogloss:0.52808
# [119]	validation_0-mlogloss:0.52611
# [120]	validation_0-mlogloss:0.52413
# [121]	validation_0-mlogloss:0.52214
# [122]	validation_0-mlogloss:0.52020
# [123]	validation_0-mlogloss:0.51830
# [124]	validation_0-mlogloss:0.51641
# [125]	validation_0-mlogloss:0.51457
# [126]	validation_0-mlogloss:0.51278
# [127]	validation_0-mlogloss:0.51099
# [128]	validation_0-mlogloss:0.50915
# [129]	validation_0-mlogloss:0.50736
# [130]	validation_0-mlogloss:0.50557
# [131]	validation_0-mlogloss:0.50384
# [132]	validation_0-mlogloss:0.50209
# [133]	validation_0-mlogloss:0.50042
# [134]	validation_0-mlogloss:0.49873
# [135]	validation_0-mlogloss:0.49707
# [136]	validation_0-mlogloss:0.49542
# [137]	validation_0-mlogloss:0.49376
# [138]	validation_0-mlogloss:0.49220
# [139]	validation_0-mlogloss:0.49061
# [140]	validation_0-mlogloss:0.48903
# [141]	validation_0-mlogloss:0.48746
# [142]	validation_0-mlogloss:0.48597
# [143]	validation_0-mlogloss:0.48447
# [144]	validation_0-mlogloss:0.48295
# [145]	validation_0-mlogloss:0.48143
# [146]	validation_0-mlogloss:0.48000
# [147]	validation_0-mlogloss:0.47857
# [148]	validation_0-mlogloss:0.47713
# [149]	validation_0-mlogloss:0.47574
# [150]	validation_0-mlogloss:0.47438
# [151]	validation_0-mlogloss:0.47298
# [152]	validation_0-mlogloss:0.47162
# [153]	validation_0-mlogloss:0.47026
# [154]	validation_0-mlogloss:0.46894
# [155]	validation_0-mlogloss:0.46761
# [156]	validation_0-mlogloss:0.46636
# [157]	validation_0-mlogloss:0.46508
# [158]	validation_0-mlogloss:0.46380
# [159]	validation_0-mlogloss:0.46254
# [160]	validation_0-mlogloss:0.46128
# [161]	validation_0-mlogloss:0.46006
# [162]	validation_0-mlogloss:0.45883
# [163]	validation_0-mlogloss:0.45760
# [164]	validation_0-mlogloss:0.45640
# [165]	validation_0-mlogloss:0.45520
# [166]	validation_0-mlogloss:0.45404
# [167]	validation_0-mlogloss:0.45288
# [168]	validation_0-mlogloss:0.45172
# [169]	validation_0-mlogloss:0.45055
# [170]	validation_0-mlogloss:0.44940
# [171]	validation_0-mlogloss:0.44831
# [172]	validation_0-mlogloss:0.44723
# [173]	validation_0-mlogloss:0.44614
# [174]	validation_0-mlogloss:0.44510
# [175]	validation_0-mlogloss:0.44406
# [176]	validation_0-mlogloss:0.44302
# [177]	validation_0-mlogloss:0.44201
# [178]	validation_0-mlogloss:0.44101
# [179]	validation_0-mlogloss:0.43999
# [180]	validation_0-mlogloss:0.43897
# [181]	validation_0-mlogloss:0.43801
# [182]	validation_0-mlogloss:0.43706
# [183]	validation_0-mlogloss:0.43607
# [184]	validation_0-mlogloss:0.43511
# [185]	validation_0-mlogloss:0.43420
# [186]	validation_0-mlogloss:0.43328
# [187]	validation_0-mlogloss:0.43239
# [188]	validation_0-mlogloss:0.43142
# [189]	validation_0-mlogloss:0.43054
# [190]	validation_0-mlogloss:0.42962
# [191]	validation_0-mlogloss:0.42877
# [192]	validation_0-mlogloss:0.42792
# [193]	validation_0-mlogloss:0.42702
# [194]	validation_0-mlogloss:0.42622
# [195]	validation_0-mlogloss:0.42535
# [196]	validation_0-mlogloss:0.42452
# [197]	validation_0-mlogloss:0.42367
# [198]	validation_0-mlogloss:0.42284
# [199]	validation_0-mlogloss:0.42200
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
from xgboost import plot_importance
plot_importance(model)
# plt.figure(figsize=(24,12))
plt.yticks(fontsize=8)
plt.show()

# %%
model.feature_importances_
# Out:
# array([0.0093014 , 0.00549552, 0.01005876, 0.00865257, 0.00556027,
#        0.01164459, 0.00862045, 0.00602034, 0.00659764, 0.08715136,
#        0.00845882, 0.00654198, 0.00605689, 0.00562892, 0.00676617,
#        0.00553598, 0.0070035 , 0.00624937, 0.0073887 , 0.        ,
#        0.0055974 , 0.00567272, 0.00661288, 0.00733814, 0.00698643,
#        0.00654291, 0.0064389 , 0.00688984, 0.00598745, 0.01710559,
#        0.02654921, 0.00990083, 0.01403508, 0.00622557, 0.0268091 ,
#        0.00664499, 0.00510012, 0.02135264, 0.32778457, 0.00752421,
#        0.00575916, 0.0060177 , 0.00549993, 0.02278937, 0.01049219,
#        0.01451571, 0.00148337, 0.16394517, 0.00696943, 0.01043921,
#        0.00625693], dtype=float32)

# %%
preds = model.predict(X_test)
preds
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix # 혼동행렬
from sklearn.metrics import accuracy_score # 정확도
from sklearn.metrics import precision_score # 정밀도
from sklearn.metrics import recall_score # 재현율
from sklearn.metrics import f1_score # f1 스코어

# %%
def cal_class_score(y_test, preds, type_average="macro"):
    mask_class_0 = y_test == 0
    mask_class_1 = y_test == 1
    mask_class_2 = y_test == 2
    
    results = pd.DataFrame(
        {
            "class0": cal_matrix(y_test[mask_class_0], preds[mask_class_0], type_average),
            "class1": cal_matrix(y_test[mask_class_1], preds[mask_class_1], type_average),
            "class2": cal_matrix(y_test[mask_class_2], preds[mask_class_2], type_average),
        }
    )
    results = results.T
    results.columns = ["accuracy", "precision", "recall", "F1"]
    return results

def cal_matrix(y_test, preds, type_average):
    result_class = []
    result_class.append(accuracy_score(y_test, preds))
    result_class.append(precision_score(y_test, preds, average=type_average).tolist())
    result_class.append(recall_score(y_test, preds, average=type_average).tolist())
    result_class.append(f1_score(y_test, preds, average=type_average).tolist())
    return result_class

# %%
test = cal_class_score(y_test, preds, type_average="macro")
# Out:
# c:\Users\ecobrain\miniconda3\envs\khs\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\ecobrain\miniconda3\envs\khs\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\ecobrain\miniconda3\envs\khs\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
test
# Out:
#         accuracy  precision    recall        F1
# class0  0.945682   0.500000  0.472841  0.486041
# class1  0.614621   0.333333  0.204874  0.253773
# class2  0.434343   0.333333  0.144781  0.201878

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, preds, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.901     0.946     0.923      3995
#            1      0.716     0.615     0.661      1108
#            2      0.741     0.434     0.548        99
#
#     accuracy                          0.865      5202
#    macro avg      0.786     0.665     0.711      5202
# weighted avg      0.859     0.865     0.860      5202
