# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random

# %%
def resumetable(df):
    print(f'Dataset shape: {df.shape}')
    summary = pd.DataFrame(df.dtypes, columns=[' Type'])
    summary = summary.reset_index()
    summary = summary.rename(columns={'index': 'Feature'})
    summary['Missing Values Count'] = df.isnull().sum().values
    summary['Missing Values Percentage'] = df.isnull().sum().values / len(df) * 100
    summary['Unique Values Count'] = df.nunique().values
    summary['First Value'] = df.iloc[0].values
    summary['Second Value'] = df.iloc[1].values
    summary['Third Value'] = df.iloc[2].values
    summary['Second to Last Value'] = df.iloc[-2].values
    summary['Last Value'] = df.iloc[-1].values
    return summary

def seed_everything(seed = 9234):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    # torch.manual_seed(seed)
    # torch.cuda.manual_seed(seed)
    # torch.backends.cudnn.deterministic = True
    # torch.backends.cudnn.benchmark = True

seed_everything()

# %%
data = pd.read_csv("../Data/Soo_T_PATIENTS_DAILY_WHOLE_0812.csv")

# %%
resumetable(data)
# Out:
# Dataset shape: (26010, 59)
#               Feature     Type  Missing Values Count  \
# 0                sido   object                     0
# 1         create_date   object                     0
# 2             sido_cd    int64                     0
# 3          weekend_yn    int64                     0
# 4              grid_x    int64                     0
# 5              grid_y    int64                     0
# 6               sat_x  float64                     0
# 7               sat_y  float64                     0
# 8              min_ta  float64                     0
# 9              max_ta  float64                     0
# 10            mean_ta  float64                     0
# 11             gap_ta  float64                     0
# 12         min_tafeel  float64                     0
# 13         max_tafeel  float64                     0
# 14        mean_tafeel  float64                     0
# 15         gap_tafeel  float64                     0
# 16             min_hm  float64                     0
# 17             max_hm  float64                     0
# 18            mean_hm  float64                     0
# 19             gap_hm  float64                     0
# 20         min_wbtemp  float64                     0
# 21         max_wbtemp  float64                     0
# 22        mean_wbtemp  float64                     0
# 23         gap_wbtemp  float64                     0
# 24             min_ws  float64                     0
# 25             max_ws  float64                     0
# 26            mean_ws  float64                     0
# 27     tropical_3days    int64                     0
# 28      heatwave_temp    int64                     0
# 29     heatalert_temp    int64                     0
# 30       ta_min_3days  float64                     0
# 31       ta_max_3days  float64                     0
# 32      gap_ta_minmax  float64                     0
# 33        popular_man    int64                     0
# 34      popular_woman    int64                     0
# 35    agriculture_man    int64                     0
# 36  agriculture_woman    int64                     0
# 37          ta_min_am    int64                     0
# 38          ta_max_am    int64                     0
# 39         ta_mean_am    int64                     0
# 40          ta_min_pm    int64                     0
# 41          ta_max_pm    int64                     0
# 42         ta_mean_pm    int64                     0
# 43     ta_min_six_am1  float64                     0
# 44     ta_max_six_am1  float64                     0
# 45    ta_mean_six_am1  float64                     0
# 46     ta_min_six_am2    int64                     0
# 47     ta_max_six_am2    int64                     0
# 48    ta_mean_six_am2    int64                     0
# 49     ta_min_six_pm1    int64                     0
# 50     ta_max_six_pm1    int64                     0
# 51    ta_mean_six_pm1    int64                     0
# 52     ta_min_six_pm2    int64                     0
# 53     ta_max_six_pm2    int64                     0
# 54    ta_mean_six_pm2    int64                     0
# 55        patientsCnt    int64                     0
# 56      jenks_cluster    int64                     0
# 57           instDate   object                     0
# 58           updtDate   object                     0
#
#     Missing Values Percentage  Unique Values Count First Value Second Value  \
# 0                         0.0                   17         경기도         충청북도
# 1                         0.0                 1530  2014-05-01   2014-05-01
# 2                         0.0                   17          31           33
# 3                         0.0                    2           0            0
# 4                         0.0                   15          60           69
# 5                         0.0                   16         120          107
# 6                         0.0                    1         0.0          0.0
# 7                         0.0                    1         0.0          0.0
# 8                         0.0                  253         9.6         10.5
# 9                         0.0                  259        24.2         23.7
# 10                        0.0                  231        16.6         17.1
# 11                        0.0                  194        14.6         13.2
# 12                        0.0                 2144       12.35        12.78
# 13                        0.0                 1943       22.04        22.16
# 14                        0.0                  223        17.0         17.5
# 15                        0.0                  142         9.7          9.4
# 16                        0.0                   97        30.0         33.0
# 17                        0.0                   73        98.0         91.0
# 18                        0.0                  739        61.1         60.0
# 19                        0.0                  120         5.4          5.6
# 20                        0.0                  246         8.8          9.3
# 21                        0.0                  234        14.2         14.9
# 22                        0.0                  229        11.6         12.0
# 23                        0.0                  120         5.4          5.6
# 24                        0.0                   76         0.3          0.0
# 25                        0.0                   91         3.5          3.7
# 26                        0.0                   96         1.7          1.6
# 27                        0.0                    4           0            0
# 28                        0.0                   49           0            0
# 29                        0.0                   37           0            0
# 30                        0.0                  243         9.6         10.5
# 31                        0.0                  246        24.2         23.7
# 32                        0.0                  213        14.6         13.2
# 33                        0.0                  170     6219813       796141
# 34                        0.0                  170     6138017       782792
# 35                        0.0                  169      186278        92687
# 36                        0.0                  169      188594        95065
# 37                        0.0                   28           9           10
# 38                        0.0                   30          21           21
# 39                        0.0                   25          13           14
# 40                        0.0                   27          14           15
# 41                        0.0                   30          24           23
# 42                        0.0                   28          20           20
# 43                        0.0                   29         9.0         10.0
# 44                        0.0                   27        13.0         14.0
# 45                        0.0                   27        10.0         12.0
# 46                        0.0                   28           9           10
# 47                        0.0                   30          21           21
# 48                        0.0                   26          15           15
# 49                        0.0                   29          21           21
# 50                        0.0                   30          24           23
# 51                        0.0                   29          22           22
# 52                        0.0                   27          14           15
# 53                        0.0                   30          21           22
# 54                        0.0                   28          17           18
# 55                        0.0                   42           0            0
# 56                        0.0                    3           0            0
# 57                        0.0                    1  2024-07-31   2024-07-31
# 58                        0.0                    1  2024-07-31   2024-07-31
#
#    Third Value Second to Last Value  Last Value
# 0        대구광역시                 경상남도       인천광역시
# 1   2014-05-01           2023-09-30  2023-09-30
# 2           22                   38          23
# 3            0                    1           1
# 4           89                   91          55
# 5           90                   77         124
# 6          0.0                  0.0         0.0
# 7          0.0                  0.0         0.0
# 8         13.5                 18.3        18.9
# 9         25.3                 25.5        23.3
# 10        19.0                 21.5        21.5
# 11        11.8                  7.2         4.4
# 12       16.29                20.86       20.11
# 13       23.66                25.05       25.09
# 14        19.6                 23.1        23.0
# 15         7.4                  4.2         5.0
# 16        27.0                 49.0        62.0
# 17        97.0                 94.0        84.0
# 18        64.7                 76.7        75.3
# 19         3.4                  4.7         5.1
# 20        12.7                 15.9        15.3
# 21        16.1                 20.6        20.4
# 22        14.2                 18.4        18.3
# 23         3.4                  4.7         5.1
# 24         0.1                  0.0         0.2
# 25         3.7                  3.3         6.7
# 26         1.9                  1.3         4.1
# 27           0                    0           0
# 28           0                    0           0
# 29           0                    0           0
# 30        13.5                 18.3        18.3
# 31        25.3                 30.8        25.0
# 32        11.8                 12.5         6.7
# 33     1241119              1636987     1499016
# 34     1252145              1614171     1498394
# 35       25045               114000       11835
# 36       24142               121775       12309
# 37          13                   18          20
# 38          21                   22          23
# 39          16                   21          21
# 40          18                   18          18
# 41          25                   25          23
# 42          22                   21          21
# 43        13.0                 21.0        20.0
# 44        14.0                 22.0        21.0
# 45        14.0                 22.0        20.0
# 46          14                   18          21
# 47          21                   21          23
# 48          17                   20          22
# 49          21                   21          21
# 50          25                   25          23
# 51          23                   23          22
# 52          18                   18          18
# 53          24                   22          21
# 54          20                   19          20
# 55           0                    0           0
# 56           0                    0           0
# 57  2024-07-31           2024-07-31  2024-07-31
# 58  2024-07-31           2024-07-31  2024-07-31

# %%
cols = ["max_tafeel", "ta_max_six_pm2", "mean_wbtemp", "popular_man", "max_ta", "popular_woman", "max_wbtemp", "ta_min_six_pm1",
        "ta_mean_six_pm2", "ta_mean_six_pm1", "mean_tafeel", "agriculture_woman", "agriculture_man", "ta_max_six_am2", "min_wbtemp",
        "jenks_cluster"]

# %%
new_data = data[cols]
print(new_data.shape)
new_data.head()
# Out:
# (26010, 16)
#    max_tafeel  ta_max_six_pm2  mean_wbtemp  popular_man  max_ta  \
# 0       22.04              21         11.6      6219813    24.2
# 1       22.16              22         12.0       796141    23.7
# 2       23.66              24         14.2      1241119    25.3
# 3       21.88              21         12.3       931536    23.6
# 4       23.95              24         14.4      1356182    25.3
#
#    popular_woman  max_wbtemp  ta_min_six_pm1  ta_mean_six_pm2  \
# 0        6138017        14.2              21               17
# 1         782792        14.9              21               18
# 2        1252145        16.1              21               20
# 3         940024        14.6              20               16
# 4        1344612        16.6              22               21
#
#    ta_mean_six_pm1  mean_tafeel  agriculture_woman  agriculture_man  \
# 0               22         17.0             188594           186278
# 1               22         17.5              95065            92687
# 2               23         19.6              24142            25045
# 3               22         17.2             128116           122465
# 4               24         19.9             229448           217473
#
#    ta_max_six_am2  min_wbtemp  jenks_cluster
# 0              21         8.8              0
# 1              21         9.3              0
# 2              21        12.7              0
# 3              20         9.5              0
# 4              22        12.2              0

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
import optuna
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import SMOTE

# %%
X = new_data.drop(columns=["jenks_cluster"])
y = new_data.jenks_cluster

seed_num = 43

# %%
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=seed_num) # 20% test data set
# SMOTE
X_resampled, y_resampled = SMOTE(random_state=seed_num).fit_resample(X_temp, y_temp)
X_train, X_valid, y_train, y_valid = train_test_split(X_resampled, y_resampled, test_size=0.125, stratify=y_resampled, random_state=seed_num) # 10% valid data set

# %%
X_train.shape, X_valid.shape, X_test.shape
# Out:
# ((41944, 15), (5993, 15), (5202, 15))

# %%
y_train.shape, y_valid.shape, y_test.shape
# Out:
# ((41944,), (5993,), (5202,))

# %%
def objective(trial):
    param = {
        'verbosity': 0,
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 1e-3, 0.1, log=True),
        'eval_stopping_rounds': 10,
        'tree_method': 'gpu_hist',
    }
    
    model = XGBClassifier(**param)
    model.fit(
        X_train, y_train,
        eval_set=[(X_valid, y_valid)],
        verbose=False,
    )
    
    y_pred = model.predict(X_valid)
    accuracy = accuracy_score(y_valid, y_pred)
    
    return accuracy

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

print(f"Best trial: {study.best_trial.value}")
print(f"Best parameters: {study.best_params}")
# Out:
# [I 2024-09-26 15:58:42,592] A new study created in memory with name: no-name-1db1941d-0fa2-47f3-9dbb-e5b47522f045
# [I 2024-09-26 15:59:08,623] Trial 0 finished with value: 0.8788586684465209 and parameters: {'n_estimators': 887, 'max_depth': 10, 'learning_rate': 0.0020211908098971064}. Best is trial 0 with value: 0.8788586684465209.
# [I 2024-09-26 15:59:13,753] Trial 1 finished with value: 0.8878691807108293 and parameters: {'n_estimators': 197, 'max_depth': 10, 'learning_rate': 0.019843724607529662}. Best is trial 1 with value: 0.8878691807108293.
# [I 2024-09-26 15:59:22,661] Trial 2 finished with value: 0.8738528282996829 and parameters: {'n_estimators': 451, 'max_depth': 9, 'learning_rate': 0.007756552180288447}. Best is trial 1 with value: 0.8878691807108293.
# [I 2024-09-26 15:59:29,604] Trial 3 finished with value: 0.9095611546804605 and parameters: {'n_estimators': 767, 'max_depth': 7, 'learning_rate': 0.05903598797414824}. Best is trial 3 with value: 0.9095611546804605.
# [I 2024-09-26 15:59:30,747] Trial 4 finished with value: 0.7907558818621725 and parameters: {'n_estimators': 260, 'max_depth': 3, 'learning_rate': 0.004841424410788734}. Best is trial 3 with value: 0.9095611546804605.
# [I 2024-09-26 15:59:31,624] Trial 5 finished with value: 0.8159519439345904 and parameters: {'n_estimators': 163, 'max_depth': 4, 'learning_rate': 0.023064770757475647}. Best is trial 3 with value: 0.9095611546804605.
# [I 2024-09-26 15:59:44,537] Trial 6 finished with value: 0.8783580844318372 and parameters: {'n_estimators': 447, 'max_depth': 10, 'learning_rate': 0.003607560802704691}. Best is trial 3 with value: 0.9095611546804605.
# [I 2024-09-26 15:59:49,357] Trial 7 finished with value: 0.8554980810946103 and parameters: {'n_estimators': 223, 'max_depth': 9, 'learning_rate': 0.0014840034346779887}. Best is trial 3 with value: 0.9095611546804605.
# [I 2024-09-26 15:59:52,335] Trial 8 finished with value: 0.8640080093442349 and parameters: {'n_estimators': 706, 'max_depth': 3, 'learning_rate': 0.055774571182788106}. Best is trial 3 with value: 0.9095611546804605.
# [I 2024-09-26 16:00:01,125] Trial 9 finished with value: 0.9204071416652762 and parameters: {'n_estimators': 814, 'max_depth': 8, 'learning_rate': 0.07453556289217111}. Best is trial 9 with value: 0.9204071416652762.
# [I 2024-09-26 16:00:08,379] Trial 10 finished with value: 0.8818621725346237 and parameters: {'n_estimators': 977, 'max_depth': 6, 'learning_rate': 0.02026718280533846}. Best is trial 9 with value: 0.9204071416652762.
# [I 2024-09-26 16:00:15,435] Trial 11 finished with value: 0.9165693308860337 and parameters: {'n_estimators': 779, 'max_depth': 7, 'learning_rate': 0.09859137101547788}. Best is trial 9 with value: 0.9204071416652762.
# [I 2024-09-26 16:00:21,457] Trial 12 finished with value: 0.9167361922242616 and parameters: {'n_estimators': 667, 'max_depth': 7, 'learning_rate': 0.09975560590228616}. Best is trial 9 with value: 0.9204071416652762.
# [I 2024-09-26 16:00:26,239] Trial 13 finished with value: 0.8923744368429835 and parameters: {'n_estimators': 643, 'max_depth': 6, 'learning_rate': 0.04160665851152323}. Best is trial 9 with value: 0.9204071416652762.
# [I 2024-09-26 16:00:33,128] Trial 14 finished with value: 0.915901885533122 and parameters: {'n_estimators': 625, 'max_depth': 8, 'learning_rate': 0.07824673643314352}. Best is trial 9 with value: 0.9204071416652762.
# [I 2024-09-26 16:00:36,243] Trial 15 finished with value: 0.8671783747705657 and parameters: {'n_estimators': 507, 'max_depth': 5, 'learning_rate': 0.035679142185963617}. Best is trial 9 with value: 0.9204071416652762.
# [I 2024-09-26 16:00:46,849] Trial 16 finished with value: 0.8825296178875355 and parameters: {'n_estimators': 880, 'max_depth': 8, 'learning_rate': 0.011423388719012892}. Best is trial 9 with value: 0.9204071416652762.
# [I 2024-09-26 16:00:50,738] Trial 17 finished with value: 0.9112297680627398 and parameters: {'n_estimators': 341, 'max_depth': 8, 'learning_rate': 0.09630074580965302}. Best is trial 9 with value: 0.9204071416652762.
# [I 2024-09-26 16:00:54,411] Trial 18 finished with value: 0.8703487401968963 and parameters: {'n_estimators': 594, 'max_depth': 5, 'learning_rate': 0.03387852243696423}. Best is trial 9 with value: 0.9204071416652762.
# [I 2024-09-26 16:01:03,869] Trial 19 finished with value: 0.8771900550642416 and parameters: {'n_estimators': 997, 'max_depth': 7, 'learning_rate': 0.011976510254978813}. Best is trial 9 with value: 0.9204071416652762.
# [I 2024-09-26 16:01:15,283] Trial 20 finished with value: 0.9209077256799599 and parameters: {'n_estimators': 858, 'max_depth': 9, 'learning_rate': 0.057459894699371294}. Best is trial 20 with value: 0.9209077256799599.
# [I 2024-09-26 16:01:26,252] Trial 21 finished with value: 0.9204071416652762 and parameters: {'n_estimators': 836, 'max_depth': 9, 'learning_rate': 0.059621454123838534}. Best is trial 20 with value: 0.9209077256799599.
# [I 2024-09-26 16:01:37,768] Trial 22 finished with value: 0.9215751710328717 and parameters: {'n_estimators': 868, 'max_depth': 9, 'learning_rate': 0.052266898413412505}. Best is trial 22 with value: 0.9215751710328717.
# [I 2024-09-26 16:01:50,350] Trial 23 finished with value: 0.913565826797931 and parameters: {'n_estimators': 912, 'max_depth': 9, 'learning_rate': 0.028812329043257128}. Best is trial 22 with value: 0.9215751710328717.
# [I 2024-09-26 16:01:58,800] Trial 24 finished with value: 0.9122309360921075 and parameters: {'n_estimators': 767, 'max_depth': 8, 'learning_rate': 0.04801367554296625}. Best is trial 22 with value: 0.9215751710328717.
# [I 2024-09-26 16:02:10,762] Trial 25 finished with value: 0.9028867011513433 and parameters: {'n_estimators': 821, 'max_depth': 9, 'learning_rate': 0.017059628650655533}. Best is trial 22 with value: 0.9215751710328717.
# [I 2024-09-26 16:02:20,965] Trial 26 finished with value: 0.9182379442683131 and parameters: {'n_estimators': 944, 'max_depth': 8, 'learning_rate': 0.06937511881215418}. Best is trial 22 with value: 0.9215751710328717.
# [I 2024-09-26 16:02:33,364] Trial 27 finished with value: 0.9128983814450192 and parameters: {'n_estimators': 708, 'max_depth': 10, 'learning_rate': 0.028577102182233683}. Best is trial 22 with value: 0.9215751710328717.
# [I 2024-09-26 16:02:44,569] Trial 28 finished with value: 0.9169030535624896 and parameters: {'n_estimators': 840, 'max_depth': 9, 'learning_rate': 0.04674920166616776}. Best is trial 22 with value: 0.9215751710328717.
# [I 2024-09-26 16:03:03,878] Trial 29 finished with value: 0.8923744368429835 and parameters: {'n_estimators': 892, 'max_depth': 10, 'learning_rate': 0.007329077963298409}. Best is trial 22 with value: 0.9215751710328717.
# [I 2024-09-26 16:03:12,363] Trial 30 finished with value: 0.8867011513432338 and parameters: {'n_estimators': 724, 'max_depth': 8, 'learning_rate': 0.015298650909607017}. Best is trial 22 with value: 0.9215751710328717.
# [I 2024-09-26 16:03:23,420] Trial 31 finished with value: 0.9235775070916069 and parameters: {'n_estimators': 853, 'max_depth': 9, 'learning_rate': 0.07120953939579289}. Best is trial 31 with value: 0.9235775070916069.
# [I 2024-09-26 16:03:35,446] Trial 32 finished with value: 0.9210745870181879 and parameters: {'n_estimators': 919, 'max_depth': 9, 'learning_rate': 0.06417808651382412}. Best is trial 31 with value: 0.9235775070916069.
# [I 2024-09-26 16:03:50,573] Trial 33 finished with value: 0.9194059736359086 and parameters: {'n_estimators': 919, 'max_depth': 10, 'learning_rate': 0.03883230051080851}. Best is trial 31 with value: 0.9235775070916069.
# [I 2024-09-26 16:04:02,746] Trial 34 finished with value: 0.9122309360921075 and parameters: {'n_estimators': 870, 'max_depth': 9, 'learning_rate': 0.02720263717334848}. Best is trial 31 with value: 0.9235775070916069.
# [I 2024-09-26 16:04:17,124] Trial 35 finished with value: 0.9237443684298348 and parameters: {'n_estimators': 944, 'max_depth': 10, 'learning_rate': 0.06861210615275119}. Best is trial 35 with value: 0.9237443684298348.
# [I 2024-09-26 16:04:31,430] Trial 36 finished with value: 0.9227432004004672 and parameters: {'n_estimators': 964, 'max_depth': 10, 'learning_rate': 0.07746195580168935}. Best is trial 35 with value: 0.9237443684298348.
# [I 2024-09-26 16:04:45,849] Trial 37 finished with value: 0.9224094777240114 and parameters: {'n_estimators': 971, 'max_depth': 10, 'learning_rate': 0.08104518551777369}. Best is trial 35 with value: 0.9237443684298348.
# [I 2024-09-26 16:04:48,816] Trial 38 finished with value: 0.8631737026530952 and parameters: {'n_estimators': 101, 'max_depth': 10, 'learning_rate': 0.0030749463262304613}. Best is trial 35 with value: 0.9237443684298348.
# [I 2024-09-26 16:05:03,197] Trial 39 finished with value: 0.9222426163857834 and parameters: {'n_estimators': 968, 'max_depth': 10, 'learning_rate': 0.07694435084447805}. Best is trial 35 with value: 0.9237443684298348.
# [I 2024-09-26 16:05:24,504] Trial 40 finished with value: 0.8942099115634907 and parameters: {'n_estimators': 992, 'max_depth': 10, 'learning_rate': 0.00683001052379881}. Best is trial 35 with value: 0.9237443684298348.
# [I 2024-09-26 16:05:38,952] Trial 41 finished with value: 0.9224094777240114 and parameters: {'n_estimators': 961, 'max_depth': 10, 'learning_rate': 0.07302555880940931}. Best is trial 35 with value: 0.9237443684298348.
# [I 2024-09-26 16:05:53,131] Trial 42 finished with value: 0.9249123977974303 and parameters: {'n_estimators': 945, 'max_depth': 10, 'learning_rate': 0.07576722959541074}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:06:07,073] Trial 43 finished with value: 0.9229100617386952 and parameters: {'n_estimators': 937, 'max_depth': 10, 'learning_rate': 0.08080743276875439}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:06:30,339] Trial 44 finished with value: 0.8721842149174036 and parameters: {'n_estimators': 796, 'max_depth': 10, 'learning_rate': 0.0010176206901782465}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:06:45,385] Trial 45 finished with value: 0.9220757550475555 and parameters: {'n_estimators': 927, 'max_depth': 10, 'learning_rate': 0.04456398011616501}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:06:50,975] Trial 46 finished with value: 0.9184048056065409 and parameters: {'n_estimators': 410, 'max_depth': 9, 'learning_rate': 0.08483700140712194}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:07:02,794] Trial 47 finished with value: 0.9229100617386952 and parameters: {'n_estimators': 737, 'max_depth': 10, 'learning_rate': 0.05902850400461404}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:07:13,053] Trial 48 finished with value: 0.9197396963123644 and parameters: {'n_estimators': 769, 'max_depth': 9, 'learning_rate': 0.058666620344299945}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:07:25,291] Trial 49 finished with value: 0.9128983814450192 and parameters: {'n_estimators': 728, 'max_depth': 10, 'learning_rate': 0.03395452902893686}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:07:34,895] Trial 50 finished with value: 0.9072250959452695 and parameters: {'n_estimators': 516, 'max_depth': 10, 'learning_rate': 0.023734571597240392}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:07:47,971] Trial 51 finished with value: 0.9229100617386952 and parameters: {'n_estimators': 895, 'max_depth': 10, 'learning_rate': 0.0957220732692475}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:08:00,993] Trial 52 finished with value: 0.9209077256799599 and parameters: {'n_estimators': 808, 'max_depth': 10, 'learning_rate': 0.05077709229484416}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:08:12,478] Trial 53 finished with value: 0.923410645753379 and parameters: {'n_estimators': 914, 'max_depth': 9, 'learning_rate': 0.09601909049951697}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:08:24,123] Trial 54 finished with value: 0.9247455364592024 and parameters: {'n_estimators': 928, 'max_depth': 9, 'learning_rate': 0.09968757624365288}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:08:36,044] Trial 55 finished with value: 0.9239112297680627 and parameters: {'n_estimators': 934, 'max_depth': 9, 'learning_rate': 0.09966550154072744}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:08:47,166] Trial 56 finished with value: 0.9215751710328717 and parameters: {'n_estimators': 996, 'max_depth': 8, 'learning_rate': 0.09778391182761384}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:08:51,495] Trial 57 finished with value: 0.8867011513432338 and parameters: {'n_estimators': 840, 'max_depth': 4, 'learning_rate': 0.06397137920299124}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:09:02,997] Trial 58 finished with value: 0.9235775070916069 and parameters: {'n_estimators': 899, 'max_depth': 9, 'learning_rate': 0.09288990138276892}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:09:11,277] Trial 59 finished with value: 0.9150675788419823 and parameters: {'n_estimators': 873, 'max_depth': 7, 'learning_rate': 0.066782298425522}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:09:15,804] Trial 60 finished with value: 0.8992157517103287 and parameters: {'n_estimators': 294, 'max_depth': 9, 'learning_rate': 0.041269570226224135}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:09:27,691] Trial 61 finished with value: 0.9242449524445187 and parameters: {'n_estimators': 935, 'max_depth': 9, 'learning_rate': 0.08913000443476678}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:09:39,426] Trial 62 finished with value: 0.9235775070916069 and parameters: {'n_estimators': 895, 'max_depth': 9, 'learning_rate': 0.0868162384178912}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:09:49,833] Trial 63 finished with value: 0.9209077256799599 and parameters: {'n_estimators': 943, 'max_depth': 8, 'learning_rate': 0.06957225231927722}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:10:01,291] Trial 64 finished with value: 0.9194059736359086 and parameters: {'n_estimators': 841, 'max_depth': 9, 'learning_rate': 0.05058403237048889}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:10:11,613] Trial 65 finished with value: 0.9217420323710996 and parameters: {'n_estimators': 949, 'max_depth': 8, 'learning_rate': 0.08790031686176522}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:10:22,904] Trial 66 finished with value: 0.9225763390622392 and parameters: {'n_estimators': 863, 'max_depth': 9, 'learning_rate': 0.07355676164874289}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:10:36,022] Trial 67 finished with value: 0.9199065576505924 and parameters: {'n_estimators': 999, 'max_depth': 9, 'learning_rate': 0.05502345292782277}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:10:42,821] Trial 68 finished with value: 0.9169030535624896 and parameters: {'n_estimators': 908, 'max_depth': 6, 'learning_rate': 0.09892947855410805}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:10:51,868] Trial 69 finished with value: 0.9200734189888203 and parameters: {'n_estimators': 819, 'max_depth': 8, 'learning_rate': 0.06389419547224712}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:11:04,884] Trial 70 finished with value: 0.8741865509761388 and parameters: {'n_estimators': 656, 'max_depth': 9, 'learning_rate': 0.005228576785714018}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:11:16,248] Trial 71 finished with value: 0.9237443684298348 and parameters: {'n_estimators': 882, 'max_depth': 9, 'learning_rate': 0.08603682730117182}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:11:27,729] Trial 72 finished with value: 0.9239112297680627 and parameters: {'n_estimators': 883, 'max_depth': 9, 'learning_rate': 0.08285865982187779}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:11:40,216] Trial 73 finished with value: 0.923410645753379 and parameters: {'n_estimators': 946, 'max_depth': 9, 'learning_rate': 0.08027081904395361}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:11:50,008] Trial 74 finished with value: 0.9200734189888203 and parameters: {'n_estimators': 877, 'max_depth': 8, 'learning_rate': 0.07009067662246558}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:12:02,957] Trial 75 finished with value: 0.8618388119472719 and parameters: {'n_estimators': 849, 'max_depth': 8, 'learning_rate': 0.002271537689045057}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:12:15,483] Trial 76 finished with value: 0.9227432004004672 and parameters: {'n_estimators': 973, 'max_depth': 9, 'learning_rate': 0.08304895892886958}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:12:23,620] Trial 77 finished with value: 0.9152344401802103 and parameters: {'n_estimators': 582, 'max_depth': 9, 'learning_rate': 0.05527114259053563}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:12:28,461] Trial 78 finished with value: 0.886033705990322 and parameters: {'n_estimators': 781, 'max_depth': 5, 'learning_rate': 0.044724274742187466}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:12:40,739] Trial 79 finished with value: 0.9230769230769231 and parameters: {'n_estimators': 925, 'max_depth': 9, 'learning_rate': 0.06695921165142552}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:12:51,376] Trial 80 finished with value: 0.9224094777240114 and parameters: {'n_estimators': 978, 'max_depth': 8, 'learning_rate': 0.08638868054971303}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:13:02,902] Trial 81 finished with value: 0.9224094777240114 and parameters: {'n_estimators': 895, 'max_depth': 9, 'learning_rate': 0.09996240325899962}. Best is trial 42 with value: 0.9249123977974303.
# [I 2024-09-26 16:13:14,876] Trial 82 finished with value: 0.9252461204738862 and parameters: {'n_estimators': 931, 'max_depth': 9, 'learning_rate': 0.08839000192227013}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:13:27,200] Trial 83 finished with value: 0.9219088937093276 and parameters: {'n_estimators': 934, 'max_depth': 9, 'learning_rate': 0.07499660944866428}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:13:42,332] Trial 84 finished with value: 0.9214083096946437 and parameters: {'n_estimators': 956, 'max_depth': 10, 'learning_rate': 0.060409615453280725}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:13:53,907] Trial 85 finished with value: 0.9235775070916069 and parameters: {'n_estimators': 871, 'max_depth': 9, 'learning_rate': 0.07715954917382874}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:14:07,938] Trial 86 finished with value: 0.9245786751209745 and parameters: {'n_estimators': 923, 'max_depth': 10, 'learning_rate': 0.08699606025818296}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:14:21,809] Trial 87 finished with value: 0.9225763390622392 and parameters: {'n_estimators': 921, 'max_depth': 10, 'learning_rate': 0.08763477074482422}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:14:36,467] Trial 88 finished with value: 0.9235775070916069 and parameters: {'n_estimators': 981, 'max_depth': 10, 'learning_rate': 0.08787587087927602}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:14:49,682] Trial 89 finished with value: 0.9217420323710996 and parameters: {'n_estimators': 820, 'max_depth': 10, 'learning_rate': 0.06402760553113962}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:15:05,804] Trial 90 finished with value: 0.9192391122976806 and parameters: {'n_estimators': 957, 'max_depth': 10, 'learning_rate': 0.03731477119432658}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:15:17,473] Trial 91 finished with value: 0.9239112297680627 and parameters: {'n_estimators': 885, 'max_depth': 9, 'learning_rate': 0.07166889712196706}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:15:29,170] Trial 92 finished with value: 0.9220757550475555 and parameters: {'n_estimators': 890, 'max_depth': 9, 'learning_rate': 0.07689488286376656}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:15:43,983] Trial 93 finished with value: 0.9242449524445187 and parameters: {'n_estimators': 913, 'max_depth': 10, 'learning_rate': 0.05353921243897136}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:15:58,971] Trial 94 finished with value: 0.9215751710328717 and parameters: {'n_estimators': 926, 'max_depth': 10, 'learning_rate': 0.05231397800447623}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:16:13,576] Trial 95 finished with value: 0.9250792591356582 and parameters: {'n_estimators': 909, 'max_depth': 10, 'learning_rate': 0.058493545605896244}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:16:32,170] Trial 96 finished with value: 0.8963791089604538 and parameters: {'n_estimators': 857, 'max_depth': 10, 'learning_rate': 0.008545048635016466}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:16:47,299] Trial 97 finished with value: 0.9215751710328717 and parameters: {'n_estimators': 914, 'max_depth': 10, 'learning_rate': 0.04597616612537475}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:16:51,507] Trial 98 finished with value: 0.8733522442849991 and parameters: {'n_estimators': 977, 'max_depth': 3, 'learning_rate': 0.060172549956287284}. Best is trial 82 with value: 0.9252461204738862.
# [I 2024-09-26 16:17:04,315] Trial 99 finished with value: 0.9214083096946437 and parameters: {'n_estimators': 798, 'max_depth': 10, 'learning_rate': 0.05522179209668268}. Best is trial 82 with value: 0.9252461204738862.
# Best trial: 0.9252461204738862
# Best parameters: {'n_estimators': 931, 'max_depth': 9, 'learning_rate': 0.08839000192227013}

# %%
# 3. 최적의 모델로 최종 테스트 데이터 성능 평가
best_model = XGBClassifier(**study.best_params)
best_model.fit(X_train, y_train)

preds = best_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix # 혼동행렬
from sklearn.metrics import accuracy_score # 정확도
from sklearn.metrics import precision_score # 정밀도
from sklearn.metrics import recall_score # 재현율
from sklearn.metrics import f1_score # f1 스코어

# %%
def cal_class_score(y_test, preds, type_average="macro"):
    mask_class_0 = y_test == 0
    mask_class_1 = y_test == 1
    mask_class_2 = y_test == 2
    
    results = pd.DataFrame(
        {
            "class0": cal_matrix(y_test[mask_class_0], preds[mask_class_0], type_average),
            "class1": cal_matrix(y_test[mask_class_1], preds[mask_class_1], type_average),
            "class2": cal_matrix(y_test[mask_class_2], preds[mask_class_2], type_average),
        }
    )
    results = results.T
    results.columns = ["accuracy", "precision", "recall", "F1"]
    return results

def cal_matrix(y_test, preds, type_average):
    result_class = []
    result_class.append(accuracy_score(y_test, preds))
    result_class.append(precision_score(y_test, preds, average=type_average).tolist())
    result_class.append(recall_score(y_test, preds, average=type_average).tolist())
    result_class.append(f1_score(y_test, preds, average=type_average).tolist())
    return result_class

# %%
test = cal_class_score(y_test, preds, type_average="macro")
# Out:
# d:\Dev_folder\E382_질병청_온열환자_과제\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\Dev_folder\E382_질병청_온열환자_과제\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\Dev_folder\E382_질병청_온열환자_과제\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
test
# Out:
#         accuracy  precision    recall        F1
# class0  0.884105   0.333333  0.294702  0.312829
# class1  0.650722   0.333333  0.216907  0.262803
# class2  0.595960   0.333333  0.198653  0.248945

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, preds, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.913     0.884     0.898      3995
#            1      0.590     0.651     0.619      1108
#            2      0.522     0.596     0.557        99
#
#     accuracy                          0.829      5202
#    macro avg      0.675     0.710     0.691      5202
# weighted avg      0.837     0.829     0.832      5202
