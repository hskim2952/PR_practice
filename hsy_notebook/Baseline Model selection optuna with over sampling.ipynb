# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random

# %%
def resumetable(df):
    print(f'Dataset shape: {df.shape}')
    summary = pd.DataFrame(df.dtypes, columns=[' Type'])
    summary = summary.reset_index()
    summary = summary.rename(columns={'index': 'Feature'})
    summary['Missing Values Count'] = df.isnull().sum().values
    summary['Missing Values Percentage'] = df.isnull().sum().values / len(df) * 100
    summary['Unique Values Count'] = df.nunique().values
    summary['First Value'] = df.iloc[0].values
    summary['Second Value'] = df.iloc[1].values
    summary['Third Value'] = df.iloc[2].values
    summary['Second to Last Value'] = df.iloc[-2].values
    summary['Last Value'] = df.iloc[-1].values
    return summary

def seed_everything(seed = 9234):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    # torch.manual_seed(seed)
    # torch.cuda.manual_seed(seed)
    # torch.backends.cudnn.deterministic = True
    # torch.backends.cudnn.benchmark = True

seed_everything()

# %%
data = pd.read_csv("../Data/Soo_T_PATIENTS_DAILY_WHOLE_0812.csv")

# %%
resumetable(data)
# Out:
# Dataset shape: (26010, 59)
#               Feature     Type  Missing Values Count  \
# 0                sido   object                     0
# 1         create_date   object                     0
# 2             sido_cd    int64                     0
# 3          weekend_yn    int64                     0
# 4              grid_x    int64                     0
# 5              grid_y    int64                     0
# 6               sat_x  float64                     0
# 7               sat_y  float64                     0
# 8              min_ta  float64                     0
# 9              max_ta  float64                     0
# 10            mean_ta  float64                     0
# 11             gap_ta  float64                     0
# 12         min_tafeel  float64                     0
# 13         max_tafeel  float64                     0
# 14        mean_tafeel  float64                     0
# 15         gap_tafeel  float64                     0
# 16             min_hm  float64                     0
# 17             max_hm  float64                     0
# 18            mean_hm  float64                     0
# 19             gap_hm  float64                     0
# 20         min_wbtemp  float64                     0
# 21         max_wbtemp  float64                     0
# 22        mean_wbtemp  float64                     0
# 23         gap_wbtemp  float64                     0
# 24             min_ws  float64                     0
# 25             max_ws  float64                     0
# 26            mean_ws  float64                     0
# 27     tropical_3days    int64                     0
# 28      heatwave_temp    int64                     0
# 29     heatalert_temp    int64                     0
# 30       ta_min_3days  float64                     0
# 31       ta_max_3days  float64                     0
# 32      gap_ta_minmax  float64                     0
# 33        popular_man    int64                     0
# 34      popular_woman    int64                     0
# 35    agriculture_man    int64                     0
# 36  agriculture_woman    int64                     0
# 37          ta_min_am    int64                     0
# 38          ta_max_am    int64                     0
# 39         ta_mean_am    int64                     0
# 40          ta_min_pm    int64                     0
# 41          ta_max_pm    int64                     0
# 42         ta_mean_pm    int64                     0
# 43     ta_min_six_am1  float64                     0
# 44     ta_max_six_am1  float64                     0
# 45    ta_mean_six_am1  float64                     0
# 46     ta_min_six_am2    int64                     0
# 47     ta_max_six_am2    int64                     0
# 48    ta_mean_six_am2    int64                     0
# 49     ta_min_six_pm1    int64                     0
# 50     ta_max_six_pm1    int64                     0
# 51    ta_mean_six_pm1    int64                     0
# 52     ta_min_six_pm2    int64                     0
# 53     ta_max_six_pm2    int64                     0
# 54    ta_mean_six_pm2    int64                     0
# 55        patientsCnt    int64                     0
# 56      jenks_cluster    int64                     0
# 57           instDate   object                     0
# 58           updtDate   object                     0
#
#     Missing Values Percentage  Unique Values Count First Value Second Value  \
# 0                         0.0                   17         경기도         충청북도
# 1                         0.0                 1530  2014-05-01   2014-05-01
# 2                         0.0                   17          31           33
# 3                         0.0                    2           0            0
# 4                         0.0                   15          60           69
# 5                         0.0                   16         120          107
# 6                         0.0                    1         0.0          0.0
# 7                         0.0                    1         0.0          0.0
# 8                         0.0                  253         9.6         10.5
# 9                         0.0                  259        24.2         23.7
# 10                        0.0                  231        16.6         17.1
# 11                        0.0                  194        14.6         13.2
# 12                        0.0                 2144       12.35        12.78
# 13                        0.0                 1943       22.04        22.16
# 14                        0.0                  223        17.0         17.5
# 15                        0.0                  142         9.7          9.4
# 16                        0.0                   97        30.0         33.0
# 17                        0.0                   73        98.0         91.0
# 18                        0.0                  739        61.1         60.0
# 19                        0.0                  120         5.4          5.6
# 20                        0.0                  246         8.8          9.3
# 21                        0.0                  234        14.2         14.9
# 22                        0.0                  229        11.6         12.0
# 23                        0.0                  120         5.4          5.6
# 24                        0.0                   76         0.3          0.0
# 25                        0.0                   91         3.5          3.7
# 26                        0.0                   96         1.7          1.6
# 27                        0.0                    4           0            0
# 28                        0.0                   49           0            0
# 29                        0.0                   37           0            0
# 30                        0.0                  243         9.6         10.5
# 31                        0.0                  246        24.2         23.7
# 32                        0.0                  213        14.6         13.2
# 33                        0.0                  170     6219813       796141
# 34                        0.0                  170     6138017       782792
# 35                        0.0                  169      186278        92687
# 36                        0.0                  169      188594        95065
# 37                        0.0                   28           9           10
# 38                        0.0                   30          21           21
# 39                        0.0                   25          13           14
# 40                        0.0                   27          14           15
# 41                        0.0                   30          24           23
# 42                        0.0                   28          20           20
# 43                        0.0                   29         9.0         10.0
# 44                        0.0                   27        13.0         14.0
# 45                        0.0                   27        10.0         12.0
# 46                        0.0                   28           9           10
# 47                        0.0                   30          21           21
# 48                        0.0                   26          15           15
# 49                        0.0                   29          21           21
# 50                        0.0                   30          24           23
# 51                        0.0                   29          22           22
# 52                        0.0                   27          14           15
# 53                        0.0                   30          21           22
# 54                        0.0                   28          17           18
# 55                        0.0                   42           0            0
# 56                        0.0                    3           0            0
# 57                        0.0                    1  2024-07-31   2024-07-31
# 58                        0.0                    1  2024-07-31   2024-07-31
#
#    Third Value Second to Last Value  Last Value
# 0        대구광역시                 경상남도       인천광역시
# 1   2014-05-01           2023-09-30  2023-09-30
# 2           22                   38          23
# 3            0                    1           1
# 4           89                   91          55
# 5           90                   77         124
# 6          0.0                  0.0         0.0
# 7          0.0                  0.0         0.0
# 8         13.5                 18.3        18.9
# 9         25.3                 25.5        23.3
# 10        19.0                 21.5        21.5
# 11        11.8                  7.2         4.4
# 12       16.29                20.86       20.11
# 13       23.66                25.05       25.09
# 14        19.6                 23.1        23.0
# 15         7.4                  4.2         5.0
# 16        27.0                 49.0        62.0
# 17        97.0                 94.0        84.0
# 18        64.7                 76.7        75.3
# 19         3.4                  4.7         5.1
# 20        12.7                 15.9        15.3
# 21        16.1                 20.6        20.4
# 22        14.2                 18.4        18.3
# 23         3.4                  4.7         5.1
# 24         0.1                  0.0         0.2
# 25         3.7                  3.3         6.7
# 26         1.9                  1.3         4.1
# 27           0                    0           0
# 28           0                    0           0
# 29           0                    0           0
# 30        13.5                 18.3        18.3
# 31        25.3                 30.8        25.0
# 32        11.8                 12.5         6.7
# 33     1241119              1636987     1499016
# 34     1252145              1614171     1498394
# 35       25045               114000       11835
# 36       24142               121775       12309
# 37          13                   18          20
# 38          21                   22          23
# 39          16                   21          21
# 40          18                   18          18
# 41          25                   25          23
# 42          22                   21          21
# 43        13.0                 21.0        20.0
# 44        14.0                 22.0        21.0
# 45        14.0                 22.0        20.0
# 46          14                   18          21
# 47          21                   21          23
# 48          17                   20          22
# 49          21                   21          21
# 50          25                   25          23
# 51          23                   23          22
# 52          18                   18          18
# 53          24                   22          21
# 54          20                   19          20
# 55           0                    0           0
# 56           0                    0           0
# 57  2024-07-31           2024-07-31  2024-07-31
# 58  2024-07-31           2024-07-31  2024-07-31

# %%
lag_cols = [
    "min_tafeel", "max_tafeel", "mean_tafeel", "gap_tafeel",
    "ta_min_six_am1", "ta_max_six_am1", "ta_mean_six_am1", "ta_min_six_am2", "ta_max_six_am2", "ta_mean_six_am2",
    "ta_min_six_pm1", "ta_max_six_pm1", "ta_mean_six_pm1", "ta_min_six_pm2", "ta_max_six_pm2", "ta_mean_six_pm2",
    "min_ws", "max_ws", "mean_ws",
]

lag_data_1 = data[lag_cols][17:-17].reset_index(drop=True)
lag_data_2 = data[lag_cols][:-34].reset_index(drop=True)
lag_data_1.columns =  ["lag1_" + col for col in lag_data_1.columns]
lag_data_2.columns =  ["lag2_" + col for col in lag_data_2.columns]

# %%
lag_data_2.shape, lag_data_1.shape
# Out:
# ((25976, 19), (25976, 19))

# %%
from category_encoders import BinaryEncoder
be = BinaryEncoder()

sido_en = be.fit_transform(data["sido"])

# %%
# data = pd.concat()pd.DataFrame([sido_en, data.jenks_cluster])
new_data = pd.concat(
    [
        sido_en, data.min_tafeel, data.max_tafeel, data.mean_tafeel, data.gap_tafeel,
        data.ta_min_six_am1, data.ta_max_six_am1, data.ta_mean_six_am1, data.ta_min_six_am2, data.ta_max_six_am2, data.ta_mean_six_am2,
        data.ta_min_six_pm1, data.ta_max_six_pm1, data.ta_mean_six_pm1, data.ta_min_six_pm2, data.ta_max_six_pm2, data.ta_mean_six_pm2,
        data.min_ws, data.max_ws, data.mean_ws,
        data.jenks_cluster,
    ],
    axis=1,
)
new_data = new_data[34:].reset_index(drop=True)
new_data = pd.concat([new_data, lag_data_1], axis=1)
new_data = pd.concat([new_data, lag_data_2], axis=1)
print(new_data.shape)
new_data
# Out:
# (25976, 63)
#        sido_0  sido_1  sido_2  sido_3  sido_4  min_tafeel  max_tafeel  \
# 0           0       0       0       0       1       10.17       18.43
# 1           0       0       0       1       0       10.26       17.55
# 2           0       0       0       1       1       12.07       19.11
# 3           0       0       1       0       0       10.75       18.73
# 4           0       0       1       0       1       13.11       20.11
# ...       ...     ...     ...     ...     ...         ...         ...
# 25971       0       1       1       0       1       18.54       23.87
# 25972       0       1       1       1       0       18.16       24.52
# 25973       0       1       1       1       1       17.84       23.65
# 25974       1       0       0       0       0       20.86       25.05
# 25975       1       0       0       0       1       20.11       25.09
#
#        mean_tafeel  gap_tafeel  ta_min_six_am1  ...  lag2_ta_mean_six_am2  \
# 0             14.4         8.3             9.0  ...                    15
# 1             14.1         7.3             9.0  ...                    15
# 2             15.7         7.0            12.0  ...                    17
# 3             14.7         8.0             8.0  ...                    15
# 4             17.0         7.0            13.0  ...                    17
# ...            ...         ...             ...  ...                   ...
# 25971         21.6         5.3            22.0  ...                    24
# 25972         21.6         6.4            15.0  ...                    22
# 25973         21.1         5.8            19.0  ...                    23
# 25974         23.1         4.2            21.0  ...                    25
# 25975         23.0         5.0            20.0  ...                    22
#
#        lag2_ta_min_six_pm1  lag2_ta_max_six_pm1  lag2_ta_mean_six_pm1  \
# 0                       21                   24                    22
# 1                       21                   23                    22
# 2                       21                   25                    23
# 3                       20                   23                    22
# 4                       22                   25                    24
# ...                    ...                  ...                   ...
# 25971                   26                   29                    28
# 25972                   24                   26                    25
# 25973                   25                   27                    26
# 25974                   26                   30                    29
# 25975                   22                   25                    24
#
#        lag2_ta_min_six_pm2  lag2_ta_max_six_pm2  lag2_ta_mean_six_pm2  \
# 0                       14                   21                    17
# 1                       15                   22                    18
# 2                       18                   24                    20
# 3                       12                   21                    16
# 4                       19                   24                    21
# ...                    ...                  ...                   ...
# 25971                   23                   26                    24
# 25972                   20                   24                    21
# 25973                   20                   25                    22
# 25974                   21                   26                    23
# 25975                   20                   22                    21
#
#        lag2_min_ws  lag2_max_ws  lag2_mean_ws
# 0              0.3          3.5           1.7
# 1              0.0          3.7           1.6
# 2              0.1          3.7           1.9
# 3              0.1          4.1           1.6
# 4              0.4          4.7           2.3
# ...            ...          ...           ...
# 25971          0.7          3.5           2.5
# 25972          0.0          1.5           0.7
# 25973          1.1          3.8           2.2
# 25974          0.0          2.9           1.4
# 25975          0.0          3.8           2.1
#
# [25976 rows x 63 columns]

# %% [markdown]
# ### Over Sampling

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
import optuna
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import SMOTE

# %%
seed_num = 43
X = new_data.drop(columns=["jenks_cluster"])
y = new_data.jenks_cluster

# %%
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=seed_num) # 20% test data set
# SMOTE
X_resampled, y_resampled = SMOTE(random_state=seed_num).fit_resample(X_temp, y_temp)
X_train, X_valid, y_train, y_valid = train_test_split(X_resampled, y_resampled, test_size=0.125, stratify=y_resampled, random_state=seed_num) # 10% valid data set

# %%
X_train.shape, X_valid.shape, X_test.shape
# Out:
# ((41874, 62), (5982, 62), (5196, 62))

# %%
y_train.shape, y_valid.shape, y_test.shape
# Out:
# ((41874,), (5982,), (5196,))

# %%
def objective(trial):
    param = {
        'verbosity': 0,
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 1e-3, 0.1, log=True),
        'eval_stopping_rounds': 10,
        'tree_method': 'gpu_hist',
    }
    
    model = XGBClassifier(**param)
    model.fit(
        X_train, y_train,
        eval_set=[(X_valid, y_valid)],
        verbose=False,
    )
    
    y_pred = model.predict(X_valid)
    accuracy = accuracy_score(y_valid, y_pred)
    
    return accuracy

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

print(f"Best trial: {study.best_trial.value}")
print(f"Best parameters: {study.best_params}")
# Out:
# [I 2024-09-26 14:54:01,140] A new study created in memory with name: no-name-00301299-8330-4b6f-9bbf-c855fb9673f3
# [I 2024-09-26 14:54:04,215] Trial 0 finished with value: 0.89518555667001 and parameters: {'n_estimators': 414, 'max_depth': 4, 'learning_rate': 0.03626060434386525}. Best is trial 0 with value: 0.89518555667001.
# [I 2024-09-26 14:54:14,030] Trial 1 finished with value: 0.9368104312938816 and parameters: {'n_estimators': 911, 'max_depth': 6, 'learning_rate': 0.048768774457028145}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:54:24,506] Trial 2 finished with value: 0.92744901370779 and parameters: {'n_estimators': 381, 'max_depth': 9, 'learning_rate': 0.025664481860579683}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:54:29,192] Trial 3 finished with value: 0.8035773988632564 and parameters: {'n_estimators': 660, 'max_depth': 4, 'learning_rate': 0.0014945341552940615}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:54:40,988] Trial 4 finished with value: 0.928284854563691 and parameters: {'n_estimators': 816, 'max_depth': 7, 'learning_rate': 0.01797992112544431}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:54:47,114] Trial 5 finished with value: 0.9294550317619525 and parameters: {'n_estimators': 918, 'max_depth': 4, 'learning_rate': 0.07852018866683637}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:54:48,751] Trial 6 finished with value: 0.8625877632898696 and parameters: {'n_estimators': 128, 'max_depth': 6, 'learning_rate': 0.025024740804909847}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:55:09,572] Trial 7 finished with value: 0.8808090939485123 and parameters: {'n_estimators': 404, 'max_depth': 10, 'learning_rate': 0.0019738064848810006}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:55:12,484] Trial 8 finished with value: 0.8605817452357071 and parameters: {'n_estimators': 320, 'max_depth': 5, 'learning_rate': 0.01294380326407234}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:55:29,616] Trial 9 finished with value: 0.876629889669007 and parameters: {'n_estimators': 474, 'max_depth': 9, 'learning_rate': 0.0020877697458128465}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:55:45,532] Trial 10 finished with value: 0.8946840521564694 and parameters: {'n_estimators': 977, 'max_depth': 7, 'learning_rate': 0.00490000185235812}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:55:50,940] Trial 11 finished with value: 0.922601136743564 and parameters: {'n_estimators': 997, 'max_depth': 3, 'learning_rate': 0.08358982293079}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:55:59,326] Trial 12 finished with value: 0.9353059177532598 and parameters: {'n_estimators': 778, 'max_depth': 6, 'learning_rate': 0.08359887337893428}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:56:06,936] Trial 13 finished with value: 0.9353059177532598 and parameters: {'n_estimators': 702, 'max_depth': 6, 'learning_rate': 0.05073772484714899}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:56:24,153] Trial 14 finished with value: 0.9130725509862923 and parameters: {'n_estimators': 783, 'max_depth': 8, 'learning_rate': 0.007964234266160202}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:56:29,218] Trial 15 finished with value: 0.9309595453025744 and parameters: {'n_estimators': 597, 'max_depth': 5, 'learning_rate': 0.056844770729695536}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:56:38,356] Trial 16 finished with value: 0.9339685723838181 and parameters: {'n_estimators': 844, 'max_depth': 6, 'learning_rate': 0.04354629621658704}. Best is trial 1 with value: 0.9368104312938816.
# [I 2024-09-26 14:56:51,358] Trial 17 finished with value: 0.9398194583751254 and parameters: {'n_estimators': 747, 'max_depth': 8, 'learning_rate': 0.08788196498756644}. Best is trial 17 with value: 0.9398194583751254.
# [I 2024-09-26 14:57:08,413] Trial 18 finished with value: 0.8911735205616851 and parameters: {'n_estimators': 701, 'max_depth': 8, 'learning_rate': 0.004337584104398719}. Best is trial 17 with value: 0.9398194583751254.
# [I 2024-09-26 14:57:23,654] Trial 19 finished with value: 0.9401537947174858 and parameters: {'n_estimators': 900, 'max_depth': 8, 'learning_rate': 0.09788737041389883}. Best is trial 19 with value: 0.9401537947174858.
# [I 2024-09-26 14:57:42,302] Trial 20 finished with value: 0.9353059177532598 and parameters: {'n_estimators': 551, 'max_depth': 10, 'learning_rate': 0.02748723864728866}. Best is trial 19 with value: 0.9401537947174858.
# [I 2024-09-26 14:57:57,283] Trial 21 finished with value: 0.9426613172851889 and parameters: {'n_estimators': 904, 'max_depth': 8, 'learning_rate': 0.0963836293234279}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 14:58:11,853] Trial 22 finished with value: 0.941156803744567 and parameters: {'n_estimators': 880, 'max_depth': 8, 'learning_rate': 0.0951868361337203}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 14:58:29,296] Trial 23 finished with value: 0.9401537947174858 and parameters: {'n_estimators': 899, 'max_depth': 9, 'learning_rate': 0.0982656611132905}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 14:58:44,639] Trial 24 finished with value: 0.9398194583751254 and parameters: {'n_estimators': 859, 'max_depth': 8, 'learning_rate': 0.06025320026942732}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 14:58:58,240] Trial 25 finished with value: 0.9378134403209629 and parameters: {'n_estimators': 956, 'max_depth': 7, 'learning_rate': 0.037233662003758626}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 14:59:13,409] Trial 26 finished with value: 0.940320962888666 and parameters: {'n_estimators': 652, 'max_depth': 9, 'learning_rate': 0.06322647879593517}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 14:59:27,488] Trial 27 finished with value: 0.9406552992310264 and parameters: {'n_estimators': 602, 'max_depth': 9, 'learning_rate': 0.062312334799238936}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 14:59:39,735] Trial 28 finished with value: 0.9190906051487797 and parameters: {'n_estimators': 269, 'max_depth': 10, 'learning_rate': 0.01743930351122626}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 14:59:52,238] Trial 29 finished with value: 0.9353059177532598 and parameters: {'n_estimators': 490, 'max_depth': 9, 'learning_rate': 0.03319582351773487}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:00:02,112] Trial 30 finished with value: 0.8864928117686393 and parameters: {'n_estimators': 593, 'max_depth': 7, 'learning_rate': 0.006719651546086994}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:00:16,715] Trial 31 finished with value: 0.9409896355733868 and parameters: {'n_estimators': 640, 'max_depth': 9, 'learning_rate': 0.0673561294187539}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:00:28,471] Trial 32 finished with value: 0.9399866265463056 and parameters: {'n_estimators': 487, 'max_depth': 9, 'learning_rate': 0.06552054244367825}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:00:47,728] Trial 33 finished with value: 0.9398194583751254 and parameters: {'n_estimators': 603, 'max_depth': 10, 'learning_rate': 0.04371900393249749}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:01:00,310] Trial 34 finished with value: 0.9391507856904046 and parameters: {'n_estimators': 697, 'max_depth': 8, 'learning_rate': 0.06805490874874263}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:01:19,221] Trial 35 finished with value: 0.9374791039786025 and parameters: {'n_estimators': 766, 'max_depth': 9, 'learning_rate': 0.030787966624622385}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:01:29,768] Trial 36 finished with value: 0.9309595453025744 and parameters: {'n_estimators': 541, 'max_depth': 8, 'learning_rate': 0.02243947521716515}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:01:49,374] Trial 37 finished with value: 0.9393179538615848 and parameters: {'n_estimators': 832, 'max_depth': 9, 'learning_rate': 0.04398432506573715}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:02:07,019] Trial 38 finished with value: 0.9401537947174858 and parameters: {'n_estimators': 654, 'max_depth': 10, 'learning_rate': 0.0734384012658408}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:02:09,875] Trial 39 finished with value: 0.8796389167502507 and parameters: {'n_estimators': 164, 'max_depth': 7, 'learning_rate': 0.018562620336501648}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:02:32,356] Trial 40 finished with value: 0.9384821130056837 and parameters: {'n_estimators': 938, 'max_depth': 9, 'learning_rate': 0.03668330431320606}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:02:47,953] Trial 41 finished with value: 0.9398194583751254 and parameters: {'n_estimators': 650, 'max_depth': 9, 'learning_rate': 0.05455620703719427}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:03:01,855] Trial 42 finished with value: 0.940320962888666 and parameters: {'n_estimators': 449, 'max_depth': 10, 'learning_rate': 0.0682118850303291}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:03:12,225] Trial 43 finished with value: 0.9389836175192243 and parameters: {'n_estimators': 540, 'max_depth': 8, 'learning_rate': 0.052429014611349245}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:03:21,289] Trial 44 finished with value: 0.9381477766633233 and parameters: {'n_estimators': 357, 'max_depth': 9, 'learning_rate': 0.07677895572971599}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:03:31,977] Trial 45 finished with value: 0.9406552992310264 and parameters: {'n_estimators': 747, 'max_depth': 7, 'learning_rate': 0.09819029903083598}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:03:44,404] Trial 46 finished with value: 0.9401537947174858 and parameters: {'n_estimators': 876, 'max_depth': 7, 'learning_rate': 0.09729226102235773}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:03:54,911] Trial 47 finished with value: 0.9396522902039451 and parameters: {'n_estimators': 728, 'max_depth': 7, 'learning_rate': 0.08116391140328318}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:04:02,339] Trial 48 finished with value: 0.8470411233701103 and parameters: {'n_estimators': 795, 'max_depth': 5, 'learning_rate': 0.003094120070878189}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:04:19,172] Trial 49 finished with value: 0.9251086593112672 and parameters: {'n_estimators': 817, 'max_depth': 8, 'learning_rate': 0.011248645843287658}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:04:28,033] Trial 50 finished with value: 0.9376462721497827 and parameters: {'n_estimators': 617, 'max_depth': 7, 'learning_rate': 0.047857842723664265}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:04:40,680] Trial 51 finished with value: 0.9424941491140086 and parameters: {'n_estimators': 687, 'max_depth': 8, 'learning_rate': 0.06225620871622899}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:04:53,572] Trial 52 finished with value: 0.940320962888666 and parameters: {'n_estimators': 725, 'max_depth': 8, 'learning_rate': 0.07689748971010409}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:05:05,462] Trial 53 finished with value: 0.941992644600468 and parameters: {'n_estimators': 684, 'max_depth': 8, 'learning_rate': 0.09973633670081142}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:05:22,988] Trial 54 finished with value: 0.8619190906051488 and parameters: {'n_estimators': 690, 'max_depth': 8, 'learning_rate': 0.0011451596621034758}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:05:33,531] Trial 55 finished with value: 0.9391507856904046 and parameters: {'n_estimators': 558, 'max_depth': 8, 'learning_rate': 0.05832125681679681}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:05:37,018] Trial 56 finished with value: 0.9119023737880307 and parameters: {'n_estimators': 628, 'max_depth': 3, 'learning_rate': 0.0883315266784336}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:05:50,393] Trial 57 finished with value: 0.9393179538615848 and parameters: {'n_estimators': 570, 'max_depth': 9, 'learning_rate': 0.07044952421073136}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:06:08,558] Trial 58 finished with value: 0.9393179538615848 and parameters: {'n_estimators': 998, 'max_depth': 8, 'learning_rate': 0.03770204917360404}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:06:18,580] Trial 59 finished with value: 0.9371447676362421 and parameters: {'n_estimators': 922, 'max_depth': 6, 'learning_rate': 0.05059035485790443}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:06:36,431] Trial 60 finished with value: 0.940320962888666 and parameters: {'n_estimators': 872, 'max_depth': 9, 'learning_rate': 0.08319852396968248}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:06:49,330] Trial 61 finished with value: 0.9409896355733868 and parameters: {'n_estimators': 747, 'max_depth': 8, 'learning_rate': 0.09404349052355637}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:07:01,906] Trial 62 finished with value: 0.940320962888666 and parameters: {'n_estimators': 682, 'max_depth': 8, 'learning_rate': 0.05903700572362509}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:07:15,100] Trial 63 finished with value: 0.9426613172851889 and parameters: {'n_estimators': 775, 'max_depth': 8, 'learning_rate': 0.09994903444123454}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:07:29,020] Trial 64 finished with value: 0.9414911400869275 and parameters: {'n_estimators': 814, 'max_depth': 8, 'learning_rate': 0.08929935842198733}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:07:40,323] Trial 65 finished with value: 0.9393179538615848 and parameters: {'n_estimators': 799, 'max_depth': 7, 'learning_rate': 0.07519675535863797}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:07:54,727] Trial 66 finished with value: 0.9404881310598462 and parameters: {'n_estimators': 830, 'max_depth': 8, 'learning_rate': 0.08716087389755205}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:08:10,423] Trial 67 finished with value: 0.9401537947174858 and parameters: {'n_estimators': 895, 'max_depth': 8, 'learning_rate': 0.06609097781298759}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:08:21,028] Trial 68 finished with value: 0.9366432631227014 and parameters: {'n_estimators': 963, 'max_depth': 6, 'learning_rate': 0.09858861364800753}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:08:32,976] Trial 69 finished with value: 0.9373119358074222 and parameters: {'n_estimators': 852, 'max_depth': 7, 'learning_rate': 0.08284628800003813}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:08:47,893] Trial 70 finished with value: 0.9394851220327649 and parameters: {'n_estimators': 784, 'max_depth': 8, 'learning_rate': 0.04223104011324279}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:09:00,966] Trial 71 finished with value: 0.9413239719157472 and parameters: {'n_estimators': 749, 'max_depth': 8, 'learning_rate': 0.0993400485078881}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:09:14,039] Trial 72 finished with value: 0.9399866265463056 and parameters: {'n_estimators': 721, 'max_depth': 8, 'learning_rate': 0.07485585420767199}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:09:30,242] Trial 73 finished with value: 0.9408224674022067 and parameters: {'n_estimators': 766, 'max_depth': 9, 'learning_rate': 0.08659512181950482}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:09:45,015] Trial 74 finished with value: 0.9401537947174858 and parameters: {'n_estimators': 814, 'max_depth': 8, 'learning_rate': 0.06234014154048859}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:09:54,697] Trial 75 finished with value: 0.9401537947174858 and parameters: {'n_estimators': 677, 'max_depth': 7, 'learning_rate': 0.09915671635449888}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:10:09,524] Trial 76 finished with value: 0.9404881310598462 and parameters: {'n_estimators': 639, 'max_depth': 9, 'learning_rate': 0.06834041344279387}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:10:22,738] Trial 77 finished with value: 0.9399866265463056 and parameters: {'n_estimators': 711, 'max_depth': 8, 'learning_rate': 0.05596914599447173}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:10:40,910] Trial 78 finished with value: 0.9391507856904046 and parameters: {'n_estimators': 753, 'max_depth': 9, 'learning_rate': 0.04842807132095366}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:10:52,927] Trial 79 finished with value: 0.9401537947174858 and parameters: {'n_estimators': 669, 'max_depth': 8, 'learning_rate': 0.08606321617664701}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:11:05,903] Trial 80 finished with value: 0.9394851220327649 and parameters: {'n_estimators': 925, 'max_depth': 7, 'learning_rate': 0.07467748216729392}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:11:20,981] Trial 81 finished with value: 0.9408224674022067 and parameters: {'n_estimators': 888, 'max_depth': 8, 'learning_rate': 0.09143334905165988}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:11:35,766] Trial 82 finished with value: 0.9409896355733868 and parameters: {'n_estimators': 848, 'max_depth': 8, 'learning_rate': 0.08876619267577983}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:11:48,616] Trial 83 finished with value: 0.9404881310598462 and parameters: {'n_estimators': 736, 'max_depth': 8, 'learning_rate': 0.09946615567985351}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:11:59,574] Trial 84 finished with value: 0.9398194583751254 and parameters: {'n_estimators': 757, 'max_depth': 7, 'learning_rate': 0.07828925458785282}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:12:17,701] Trial 85 finished with value: 0.9413239719157472 and parameters: {'n_estimators': 805, 'max_depth': 9, 'learning_rate': 0.06840437863473642}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:12:38,767] Trial 86 finished with value: 0.9421598127716483 and parameters: {'n_estimators': 771, 'max_depth': 10, 'learning_rate': 0.06627570183283508}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:13:00,973] Trial 87 finished with value: 0.9414911400869275 and parameters: {'n_estimators': 815, 'max_depth': 10, 'learning_rate': 0.061566329287409974}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:13:25,633] Trial 88 finished with value: 0.941156803744567 and parameters: {'n_estimators': 806, 'max_depth': 10, 'learning_rate': 0.04074208012654053}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:13:51,100] Trial 89 finished with value: 0.9396522902039451 and parameters: {'n_estimators': 781, 'max_depth': 10, 'learning_rate': 0.031757681833517966}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:14:14,320] Trial 90 finished with value: 0.9399866265463056 and parameters: {'n_estimators': 831, 'max_depth': 10, 'learning_rate': 0.05626745533775366}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:14:36,933] Trial 91 finished with value: 0.9418254764292878 and parameters: {'n_estimators': 866, 'max_depth': 10, 'learning_rate': 0.06813638706669542}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:15:01,832] Trial 92 finished with value: 0.9404881310598462 and parameters: {'n_estimators': 857, 'max_depth': 10, 'learning_rate': 0.04781814609912996}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:15:23,274] Trial 93 finished with value: 0.9416583082581077 and parameters: {'n_estimators': 772, 'max_depth': 10, 'learning_rate': 0.06340856944244715}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:15:43,609] Trial 94 finished with value: 0.9389836175192243 and parameters: {'n_estimators': 703, 'max_depth': 10, 'learning_rate': 0.0595130276351288}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:16:18,957] Trial 95 finished with value: 0.9187562688064193 and parameters: {'n_estimators': 766, 'max_depth': 10, 'learning_rate': 0.006268209734719326}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:16:51,622] Trial 96 finished with value: 0.9343029087261785 and parameters: {'n_estimators': 941, 'max_depth': 10, 'learning_rate': 0.014180037030066168}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:17:13,008] Trial 97 finished with value: 0.9414911400869275 and parameters: {'n_estimators': 784, 'max_depth': 10, 'learning_rate': 0.063198137762562}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:17:37,543] Trial 98 finished with value: 0.9406552992310264 and parameters: {'n_estimators': 871, 'max_depth': 10, 'learning_rate': 0.052771209246798095}. Best is trial 21 with value: 0.9426613172851889.
# [I 2024-09-26 15:18:05,611] Trial 99 finished with value: 0.9391507856904046 and parameters: {'n_estimators': 833, 'max_depth': 10, 'learning_rate': 0.02683122305818992}. Best is trial 21 with value: 0.9426613172851889.
# Best trial: 0.9426613172851889
# Best parameters: {'n_estimators': 904, 'max_depth': 8, 'learning_rate': 0.0963836293234279}

# %%
# 3. 최적의 모델로 최종 테스트 데이터 성능 평가
best_model = XGBClassifier(**study.best_params)
best_model.fit(X_train, y_train)

preds = best_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix # 혼동행렬
from sklearn.metrics import accuracy_score # 정확도
from sklearn.metrics import precision_score # 정밀도
from sklearn.metrics import recall_score # 재현율
from sklearn.metrics import f1_score # f1 스코어

# %%
def cal_class_score(y_test, preds, type_average="macro"):
    mask_class_0 = y_test == 0
    mask_class_1 = y_test == 1
    mask_class_2 = y_test == 2
    
    results = pd.DataFrame(
        {
            "class0": cal_matrix(y_test[mask_class_0], preds[mask_class_0], type_average),
            "class1": cal_matrix(y_test[mask_class_1], preds[mask_class_1], type_average),
            "class2": cal_matrix(y_test[mask_class_2], preds[mask_class_2], type_average),
        }
    )
    results = results.T
    results.columns = ["accuracy", "precision", "recall", "F1"]
    return results

def cal_matrix(y_test, preds, type_average):
    result_class = []
    result_class.append(accuracy_score(y_test, preds))
    result_class.append(precision_score(y_test, preds, average=type_average).tolist())
    result_class.append(recall_score(y_test, preds, average=type_average).tolist())
    result_class.append(f1_score(y_test, preds, average=type_average).tolist())
    return result_class

# %%
test = cal_class_score(y_test, preds, type_average="macro")
# Out:
# d:\Dev_folder\E382_질병청_온열환자_과제\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\Dev_folder\E382_질병청_온열환자_과제\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\Dev_folder\E382_질병청_온열환자_과제\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
test
# Out:
#         accuracy  precision   recall        F1
# class0  0.933300   0.500000  0.46665  0.482750
# class1  0.600181   0.333333  0.20006  0.250047
# class2  0.450000   0.333333  0.15000  0.206897

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, preds, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.898     0.933     0.916      3988
#            1      0.676     0.600     0.636      1108
#            2      0.652     0.450     0.533       100
#
#     accuracy                          0.853      5196
#    macro avg      0.742     0.661     0.695      5196
# weighted avg      0.846     0.853     0.848      5196
